# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import urllib.request
import time
from urllib.request import urlopen
import zipfile
import wget

import datetime as dt
from datetime import datetime
import zipfile 

import re
import seaborn as sns
import matplotlib.pyplot as plt

import statistics

from py7zr import unpack_7zarchive
import shutil

import os
from pyunpack import Archive
import zipfile

from lxml import etree
import lxml
from copy import deepcopy

# %%
def get_data():
    import zipfile
    import wget

    full_link = 'http://wwm.phy.bme.hu/LD/ld_en_wiki.zip'
    wget.download(full_link, "ld_en_file.zip")

    with zipfile.ZipFile('ld_en_file.zip',"r") as zip_ref:
        zip_ref.extractall("en_light_dump.txt")
    #file = open(r"en_light_dump.txt/en_wiki.txt", "r")
get_data()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-0fcf539fdc93> in <module>
#       9         zip_ref.extractall("en_light_dump.txt")
#      10     #file = open(r"en_light_dump.txt/en_wiki.txt", "r")
# ---> 11 get_data()
#
# <ipython-input-2-0fcf539fdc93> in get_data()
#       4
#       5     full_link = 'http://wwm.phy.bme.hu/LD/ld_en_wiki.zip'
# ----> 6     wget.download(full_link, "ld_en_file.zip")
#       7
#       8     with zipfile.ZipFile('ld_en_file.zip',"r") as zip_ref:
#
# ~/.local/lib/python3.6/site-packages/wget.py in download(url, out, bar)
#     524     else:
#     525         binurl = url
# --> 526     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527     filename = detect_filename(url, out, headers)
#     528     if outdir:
#
# /opt/conda/lib/python3.6/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     275
#     276             while True:
# --> 277                 block = fp.read(bs)
#     278                 if not block:
#     279                     break
#
# /opt/conda/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# /opt/conda/lib/python3.6/http/client.py in readinto(self, b)
#     491         # connection, and the user is reading more bytes than will be provided
#     492         # (for example, reading in 1k chunks)
# --> 493         n = self.fp.readinto(b)
#     494         if not n and b:
#     495             # Ideally, we would raise IncompleteRead if the content-length
#
# /opt/conda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#download light dump data
headers = requests.utils.default_headers()
headers.update({'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'})

url = 'http://wwm.phy.bme.hu/light.html'

opened = urlopen(url)

soup = BeautifulSoup(opened, 'lxml')
all_links = soup.findAll('a')

en_link = soup.findAll('a')[4]
#print(en_link)
link = en_link.get("href")

full_link = url+link
#print(full_link)
#full_link2 = 'http://wwm.phy.bme.hu/LD/ld_en_wiki.zip'
#full_link2
right_link = 'http://wwm.phy.bme.hu/LD/ld_en_wiki.zip'

# %%
wget.download(right_link, "en_file.zip")

import zipfile
with zipfile.ZipFile("en_file.zip", "r") as zip_ref:
    zip_ref.extractall("light_dump_en_txt")

# %%
#download light dump data
headers = requests.utils.default_headers()
headers.update({'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'})

url = 'http://wwm.phy.bme.hu/light.html'

opened = urlopen(url)

soup = BeautifulSoup(opened, 'lxml')
all_links = soup.findAll('a')
all_links
# Out:
# [<a href="index.html"><font size="4">Return Home</font></a>,
#  <a href="./LD/ld_ar_wiki.zip">ar</a>,
#  <a href="./LD/ld_cs_wiki.zip">cs</a>,
#  <a href="./LD/ld_de_wiki.zip">de</a>,
#  <a href="./LD/ld_en_wiki.zip">en</a>,
#  <a href="./LD/ld_es_wiki.zip">es</a>,
#  <a href="./LD/ld_fa_wiki.zip">fa</a>,
#  <a href="./LD/ld_fr_wiki.zip">fr</a>,
#  <a href="./LD/ld_he_wiki.zip">he</a>,
#  <a href="./LD/ld_hu_wiki.zip">hu</a>,
#  <a href="./LD/ld_ja_wiki.zip">ja</a>,
#  <a href="./LD/ld_pt_wiki.zip">pt</a>,
#  <a href="./LD/ld_simple_wiki.zip">simple</a>,
#  <a href="./LD/ld_ro_wiki.zip">ro</a>,
#  <a href="./LD/ld_zh_wiki.zip">zh</a>,
#  <a href="LD/ld_all.zip">all</a>]

# %%
en_link = soup.findAll('a')[4]
#print(en_link)
link = en_link.get("href")
link
# Out:
# './LD/ld_en_wiki.zip'

# %% [markdown]
# ## Descriptive Stats

# %%
def get_edit_num(file):
    edit_num = {}
    art = file.readline()
    ct = 0

    for i in file:
        if i[0] != "^":
            edit_num[art.rstrip()] = ct
            art = i
            ct = 0
        else:
            ct +=1

    edit_num[art] = ct
    return edit_num

# %%
edit_num = get_edit_num(open("en_light_dump.txt/en_wiki.txt", "r"))

# %%
edit_num
# Out:
# {'Blackboard': 2,
#  'Coimbatore_tile_company': 2,
#  'The_moonstone_2': 2,
#  'African_Hunting_Wasps': 2,
#  'Morgan_Sheardown': 2,
#  'Hymenocaris': 2,
#  'Erica_barstein': 2,
#  'Ben_clarke': 4,
#  'British_association_for_cognitive_and_behavioural_psychotherapies': 2,
#  'Ocportal': 3,
#  'British_Association_for_Cognitive_and_Behavioural_Psychotherapies': 2,
#  'Onemorelevel': 2,
#  'Flake_ice_machine': 2,
#  'Andre_Andrade': 2,
#  'Andrew_K_Skinner': 4,
#  'Lock_thief': 3,
#  'Enrico_Scarampi': 2,
#  'Perfect_Week': 2,
#  'Alexander_Grant_Ruthven': 3,
#  'Number_Theory_-The_Queen_of_Mathematics': 2,
#  'Bangi-Ntomba_languages': 3,
#  'CCText': 7,
#  'Hydroxy-1,4-benzoquinone': 2,
#  'Creek_Freedmen': 3,
#  'Parks_and_recreations_season_2': 2,
#  'Danny_christie': 2,
#  'Mai_Xa': 2,
#  'Shahid_kapoor_and_amrita_rao': 3,
#  'Soren': 2,
#  'Ahoora': 2,
#  "Ali_al-Uraidhi_ibn_Ja'far_al-Sadiq": 14,
#  'Jouhet_i_France': 2,
#  'Nutrinit': 2,
#  '2,5-dihydroxy-1,4-benzoquinone': 3,
#  'Chilldrin_of_da_Ghetto_(album)': 2,
#  '2,5-Dihydroxy-1,4-benzoquinone': 2,
#  'Manda_(Kingdom)': 2,
#  'Rex_Solomon': 13,
#  'Body_guard_film': 4,
#  'Jiangmen_star_park': 7,
#  'Runbox': 94,
#  'Sunlight_Solar_Energy': 2,
#  'Gran_Hermano_(Spain)_All_Stars': 4,
#  'Where_Flamingos_Fly': 2,
#  'YHI_International_Limited': 2,
#  'Karen_Schnaubelt_Turner_Dick': 6,
#  'Larry_loonin': 2,
#  'GrowthBusters': 4,
#  'List_of_Major_District_Roads_in_Himachal_Pradesh': 3,
#  'Sublime_Text': 5,
#  'The_Keys_of_This_Blood': 2,
#  'Sheridan_School_District_(Oregon)': 3,
#  'Yash(kannada)': 3,
#  'List_of_films_based_on_civics_books': 6,
#  'Dahil_Minahal_Mo_Ako': 4,
#  'Asa_Ransom': 2,
#  'Dagh_Dehlvi': 3,
#  'Nawab_Mirza_Khan_Dagh': 5,
#  'Jean_Pierre_Warner': 5,
#  '2010_W-League_Season': 18,
#  'The_debate_Against_Sakaology': 4,
#  'Ann_Louise_Bardach': 2,
#  'Aqua_(producer)': 4,
#  'Mudrá': 2,
#  'Die_Frau_ohne_Schatten_discography': 3,
#  'Devrajiya': 11,
#  'Exchequer_of_Chester': 2,
#  'Phi_Sigma_Chi_Multicultural_Fraternity': 6,
#  'Air_units': 3,
#  'Zhang_Yunshen': 2,
#  'CBU-59_APAM': 4,
#  'Captain_Barbell:_Ang_Pagbabalik': 3,
#  'B.A.N_MONDAYS_CHERRY_MARTINEZ': 8,
#  'Joey_Saka': 9,
#  'Cycling_in_Detroit': 8,
#  'Amberg_Historical_Society': 2,
#  'Tbilisi_central_station': 4,
#  'Dimemebfe': 4,
#  'Norman_Fair_Trade': 5,
#  'Mali_Ston_Channel': 5,
#  'Bill_Clymer': 5,
#  'Abildgaardia_ovata': 4,
#  'Fleuron_(typography)': 7,
#  'JUSCANZ': 2,
#  'The_Rainwater_LP': 2,
#  '39th_Brigade_Support_Battalion_(United_States)': 16,
#  'George_I,_Prince_of_Waldeck_and_Pyrmont': 5,
#  'James_Craig_(Irish_professor)': 2,
#  'Finnikin_of_the_Rock': 6,
#  'KE-110': 2,
#  'Der_Rosenkavalier_discography': 11,
#  'Richard_Bentley_(publisher)': 12,
#  'Marcin_Ruar': 3,
#  'Lee_Hunt_(footballer)': 2,
#  'Sayed_Mansoor_Naderi': 14,
#  "Tukey's_test_of_additivity": 2,
#  'Racovian_Academy': 2,
#  'Aphrodite_(comics)': 2,
#  "General_Staff_(Vietnam_People's_Army)": 3,
#  'Pat_Friel': 2,
#  'Hydroxybenzoquinone': 3,
#  'Matt_Wedgley': 4,
#  'Y.H.I.': 3,
#  'Fotografisk_Center': 4,
#  'Palais_Thurn_und_Taxis': 2,
#  'Broken_Bones_&_Bloody_Kisses': 3,
#  'Dr._David_Sanders': 7,
#  'The_Circus_Tents': 3,
#  'Korean_Service_Corps': 3,
#  'Joachim_Stegmann': 3,
#  'Mail/Express_Indian_trains': 2,
#  'Tyrrell_018': 3,
#  'SS_Atrato': 3,
#  '2005_Washington_Mystics_season': 2,
#  'Edwin_Elias_Ramos': 2,
#  'Andrzej_Wiszowaty': 2,
#  'Aimini': 3,
#  'Kibuye,_Uganda': 4,
#  'Apple_blue': 6,
#  'Palaeocuma': 2,
#  'Lock_Hospital,_Dublin': 2,
#  'Starr_Piano_Company': 2,
#  'Macchi_M.14': 3,
#  'Heavy_breath': 2,
#  'National_horse_show': 3,
#  'Dr._Jordan_Tama': 2,
#  'Stephen_Morehouse_Avery': 12,
#  'Jordan_Tama': 9,
#  'Industrial_revolution': 9,
#  'Jimmy_Barkan': 5,
#  'MyZone': 3,
#  'Shteynberg': 2,
#  'The_Trumpets_of_Summer': 4,
#  'RTI-229': 5,
#  'Christopher_Sandius': 4,
#  'Quinalizarin': 2,
#  'Merryland_international': 2,
#  'Dick_Crocker': 4,
#  'Macchi_M.71': 2,
#  'Action_Forms': 15,
#  '2005_Los_Angeles_Sparks_season': 4,
#  'Shimon_Shteynberg': 3,
#  'OpenDrive': 3,
#  'Jonathan_Sheldon': 3,
#  'Tetrahydroxyanthraquinone': 2,
#  "Luigi's_mansion_2": 3,
#  'HP_Pavilion_dv_1658': 58,
#  '1_February_2010_Baghdad_bombing': 3,
#  'Timeline_of_the_1998_Atlantic_hurricane_season': 6,
#  'Eway': 7,
#  'Church_of_the_Holy_Ghost,_Bern': 3,
#  'Timeline_of_progressive_rock_(1980–1989)': 2,
#  'Trinity_Community': 3,
#  'Crumbling': 3,
#  'New_Century_Club': 3,
#  'The_best_of_g_love_&_special_sauce': 2,
#  'Anelosimus_eximius': 2,
#  'Naru2u': 3,
#  'New_Century_Club_(Wilmington,_Delaware)': 2,
#  'Miguel_Mancillas': 2,
#  'TEDxCalcutta': 3,
#  "Delaware_Children's_Theatre": 4,
#  'Amjad_Aly': 18,
#  'Hercules_Underhill': 10,
#  'Lake_Sabrina': 17,
#  'Copper_fittings': 2,
#  'List_of_awards_and_nominations_received_by_Michelle_Pfeiffer': 9,
#  'Trinité_(typeface)': 2,
#  'Pfeiferbrunnen': 2,
#  'Diesel_automobiles': 4,
#  "Wu_Tang_Clan_(Comin'_In_For_a_Win)": 5,
#  '2005_Detroit_Shock_season': 4,
#  'Spitalgasse': 3,
#  'Friedrich_Karl_August,_Prince_of_Waldeck_and_Pyrmont': 4,
#  'CF360': 2,
#  'José_Alesio_da_Silva': 3,
#  'Chengdu_Meishi_International_School,an_IB_World_School': 19,
#  'Georges_Conchon': 2,
#  'The_Black_Dog,_Dublin': 2,
#  'Larry_Kidney': 2,
#  'Bruce_Mitchell_(scholar)': 9,
#  'Diva_Zappa': 18,
#  'Suat_Suna': 5,
#  'Suat_suna': 3,
#  'John_Duncan_Forsyth': 6,
#  'Kampen_Theological_University_of_the_Reformed_Churches_(Liberated)': 2,
#  'Gordon_Kirkland': 2,
#  'Brainfuck/C++_Interpreter': 2,
#  'Hong_Kong_twenty-cent_coin': 4,
#  'Joint_Elimination_Coordination_Element': 2,
#  'Hannah_Montana_4': 4,
#  'Julian_Assange': 2,
#  'Global_Forum_on_Transparency_and_Exchange_of_Information': 2,
#  "Vietnamese_People's_Air_Force_Museum,_Saigon": 2,
#  'Layton_&_Forsyth': 14,
#  'VKV_Koç_Özel_Lisesi': 2,
#  'Vkv_koc_ozel_lisesi': 2,
#  'TWTV-_Time_Warner_Television': 3,
#  'DAISY_award': 3,
#  'Jürgen_W._Falter': 2,
#  'Etha,_NB': 2,
#  'West_Prairie_High_School': 5,
#  'Abilio': 3,
#  'Schutzhaft': 3,
#  'Who_Wants_to_Be_a_Millionaire?_(Turkey)': 2,
#  "4th_Corps_(Vietnam_People's_Army)": 2,
#  'Mortgage_elimination': 2,
#  'Bridgewater_class_sloop': 2,
#  'Klencke_Atlas': 5,
#  'IKEA_Heights': 2,
#  'Keith_D._Black': 19,
#  "Fool's_Gold_(album)": 14,
#  'Leader_Of_3': 16,
#  'Calle_7_(Third_Season)': 4,
#  'Sleepy_Tigers': 3,
#  'Perseus_(munition)': 2,
#  'Rememberize': 3,
#  'Courage_the_Cowardly_Dog_(character)': 2,
#  "3rd_Corps_(Vietnam_People's_Army)": 5,
#  'René_Boileau': 2,
#  'Pritam_Saini': 15,
#  'Benefit_of_the_Doubt_(album)': 2,
#  'Macon_Transit_Authority': 2,
#  '4nd_Regiment_Ranger_Airbone_Alpine': 2,
#  'Hack_Point,_Maryland': 5,
#  'Oklahoma_County_Courthouse': 12,
#  'Stansbury_Elementary_School': 2,
#  'Decatur_Public_Transit_System': 2,
#  'Jack_Kennedy': 2,
#  'Rose_Connors': 24,
#  'W._Albert_Noyes,_Jr.': 4,
#  'David_R._Cooke': 34,
#  'Pirates_and_gold': 3,
#  'John_Joscelyn': 10,
#  'Rose_Island,_Bahamas': 5,
#  'Cedar_Rapids_Transit': 4,
#  'Danny_Quayle': 2,
#  'Minuscule_599': 4,
#  'WWE_Royal_Rumble_2010_Match_Results': 2,
#  'Michael_Fishel': 3,
#  'Carlos_Biasutto': 6,
#  'Thomas_Stanton_(Medal_of_Honor_recipient)': 4,
#  'Seal_River': 3,
#  'South_Tahoe_Area_Transit_Authority': 3,
#  'Xylosma_flexuosa': 2,
#  'Thomas_Jefferson_Building_university_of_virginia': 3,
#  'List_of_NBC_Saturday_Night_at_the_Movies_Titles': 15,
#  'René_Boileau_(ice_hockey)': 4,
#  'Netherlands_East_Indies_Forces_Intelligence_Service': 7,
#  "2nd_Corps_(Vietnam_People's_Army)": 5,
#  'Andaman_Boatyard': 2,
#  'Self-encrypting_drive': 3,
#  'Hydroxyquinone': 6,
#  'Edith_Josie': 3,
#  'Running_with': 2,
#  'Rockend': 2,
#  'Soulbook_tour': 7,
#  'Matt_Figger': 2,
#  'Ham_font': 3,
#  'Isidor_Sârbu_(disambiguation)': 2,
#  "TNN's_Alternative_Lunch": 3,
#  'Tatanka_(musician)': 5,
#  'Temperature_Altering_Composite_Material': 2,
#  'Susie_Field': 3,
#  'Medical_conditions_related_to_autism': 14,
#  'Dalonte_Hill': 2,
#  "Rachel's_Shoe": 4,
#  'Domhnall_mac_Alasdair': 2,
#  'Sufyan_ibn_`Uyaynah': 6,
#  'Taurus_(G.I._Joe)': 2,
#  'Laryngeal_saccules': 2,
#  'Texas_Tech_Lady_Raiders_basketball': 3,
#  'Lubov_Azria': 6,
#  "1st_Corps_(Vietnam_People's_Army)": 4,
#  'Tasos_Bougas': 26,
#  'Small_mammals_of_Yellowstone_National_Park': 2,
#  "I_Keep_On_Lovin'_You_(Reba_McEntire_song)": 9,
#  'Over_You': 3,
#  'Nopaltilla': 3,
#  'Winston_"Flames"_Jarrett': 2,
#  'Williamsfield_High_School': 2,
#  'Geoffrey_Hebden': 3,
#  '2008_European_Mountain_Running_Championships': 2,
#  '5,8-dihydroxy-1,4-naphthalenedione': 2,
#  'Ferrari_F93A': 6,
#  'Bob_Black_(comedy_writer)': 20,
#  '2010_AF1_season': 6,
#  'Walter_Schmiele': 4,
#  "Fool's_Gold_(band)": 20,
#  'Benjamin_Welles': 3,
#  'ActiveVideo_Networks': 12,
#  'Friedrich_Anton_Ulrich,_Prince_of_Waldeck_and_Pyrmont': 8,
#  'City_of_Lompoc_Transit': 3,
#  'Colby_Village_Elementary_School': 4,
#  'Caleb_leibowitz': 3,
#  'The_General_Idea_of_the_Revolution_in_the_Nineteenth_Century': 13,
#  'National_Neighborhood_Watch_Program': 4,
#  'Immersion_baptism': 24,
#  '1991_ACB_Playoffs': 2,
#  'Kitten_mittons': 3,
#  'Riverside_Elementary_School_District_(Arizona)': 4,
#  'Understen': 2,
#  'Caleb_Leibowitz': 15,
#  'The_Passaic_Textile_Strike': 4,
#  'Weiss_Building_&_Development': 2,
#  'Wyoming_Highway_33': 2,
#  'Arthur_Schnabel_(judoka)': 2,
#  'Big_and_Small_(TV_show)': 13,
#  'Tom_Billeter': 35,
#  'Suja_Karthika': 5,
#  'Joachim_Werner_(disambiguation)': 4,
#  'Joachim_Werner_(archaeologist)': 2,
#  'Karl_Westa': 10,
#  'Larry_L._Hereth': 24,
#  'Schauplatzgasse': 3,
#  'Tjärven': 2,
#  'Delta_Technical_College': 4,
#  'Monty_Ravenscroft': 4,
#  'Charlotte_Buff': 5,
#  'Midwest_Technical_Institute': 2,
#  'Thurlow_Park_ward': 3,
#  'Technology_Scouting': 6,
#  'Erasto_Sampson': 2,
#  'Alfred_Birnbaum': 25,
#  '5,8-Dihydroxy-1,4-naphthoquinone': 3,
#  'Arithmaurel': 5,
#  'Punctum_blandianum': 2,
#  'Arma_Shahidi_Fitzgerald': 2,
#  '4th_Regiment_Tennessee_Volunteer_Cavalry': 2,
#  'Recipe_of_a_Hoe': 3,
#  'Söderarm': 2,
#  'Vine_training_systems': 17,
#  'Wyoming_Highway_32': 2,
#  'Arne_Fahlstrøm': 4,
#  'Tulse_Hill_ward': 5,
#  'Ohio_State_Route_158': 2,
#  'Brixton_Hill_ward': 5,
#  'Galli-Curci_Theatre': 6,
#  'Jerry_Berndt': 24,
#  'Dezső_Németh': 11,
#  '19104': 3,
#  'Hjalmar_Welhaven': 2,
#  'Waubesa_intermediate_school': 2,
#  'Itzel_Figueroa': 27,
#  "We'll_Be_a_Dream": 3,
#  'Raúl_Othacehé': 7,
#  'Henrietta_Lack': 2,
#  'Sophia_Handa': 4,
#  'Nikolaos_Papanikolopoulos': 34,
#  'Volcano_Nut': 4,
#  'Mansfield_Giants': 4,
#  '"Earth,_Inc."': 2,
#  'William_Bastone': 16,
#  'Del_Tenney': 4,
#  "Top_O'_The_River": 9,
#  'Stockwell_ward': 5,
#  'Parademon_(Secret_Six)': 4,
#  'Mercury_Fulminate_Synthesis': 11,
#  'Clapham_Town_ward': 4,
#  'Nathan_Glick': 3,
#  'Spaghetti_Bowl_(Las_Vegas)': 2,
#  'Betaferon': 2,
#  'Hilary_Rose_(sociologist)': 13,
#  'Bulldog_Drummond_Comes_Back': 2,
#  'Edward_Mariner': 2,
#  'Socialist_Workers_and_Peasants_Party_of_Latvia': 2,
#  'Gleb_Vseslavich': 6,
#  'Rouge_warrior': 2,
#  'WWF64': 2,
#  'All_I_Do_Is_Win': 12,
#  'University_of_Miami_School_of_Business_Administration': 7,
#  'Conditions_on_Transformations': 4,
#  '1999_Polish_Figure_Skating_Championships': 2,
#  'Herne_Hill_ward': 4,
#  'Edmonde_Charles-Roux': 18,
#  'Sin_Querer': 2,
#  'List_of_The_First_48_episodes': 38,
#  'Kagan_Söylemezgiller': 4,
#  'Staying_Power_(album)': 2,
#  'Help_(2010_film)': 4,
#  'Frank_Hopkins_(cricketer)': 2,
#  'KDX54': 2,
#  '1889_American_Cup': 2,
#  'Digicel_Haiti_Earthquake_Relief_Fund': 4,
#  'Donald_Macleay': 5,
#  'Ferndale_ward': 5,
#  'Iceland_at_the_2010_Winter_Olympics': 2,
#  'KEC49': 4,
#  'Transmitter_mast': 2,
#  'Coldharbour_ward': 7,
#  'Bwamiramira': 9,
#  'Graphic_Nonfiction': 5,
#  'River_City_Raiders': 5,
#  'Brian_Ickler': 42,
#  'Thorvald_Lammers': 3,
#  'Peru_at_the_2010_Winter_Olympics': 3,
#  'Haemoconia': 3,
#  '2012_baseball_hall_of_fame_ballot': 3,
#  'Dihydroxynaphthoquinone': 3,
#  'Harlakenden': 4,
#  'KHB49': 4,
#  'Hilary_Rose_(disambiguation)': 5,
#  'Rugby_League_Conference_Yorkshire_Premier': 6,
#  'Morten_Wormskjold': 6,
#  "St._Mungo's_High_school_Falkirk": 5,
#  'Amelia_Goes_to_the_Ball': 12,
#  "Prince's_ward": 4,
#  'Solo_(Iyaz_song)': 2,
#  'Woodbury_Point': 4,
#  'Barbara_Corcoran': 9,
#  'Kulachi_(Karachi)': 9,
#  'Marius-Ary_Leblond': 4,
#  'Fredrick_I._Eglin': 3,
#  'Foosball_Community_Malaysia': 2,
#  'Edward_Arthur_Walton': 9,
#  'Massive_Australian_Precambrian/Cambrian_Impact_Structure': 2,
#  'Ringgo_Ramelo': 9,
#  'Agii_Deka': 7,
#  'CASC': 2,
#  'Dirty_Rig': 17,
#  'Tantiga_may': 4,
#  'Crann_Tara': 3,
#  'Hand_that_Rocks_the_Cradle': 2,
#  'Royal_International_Horse_Show': 5,
#  "Finnish_People's_Delegation": 4,
#  'Thermomonas': 2,
#  'Golf_Stream': 2,
#  'Environmental_Investment_Organisation': 10,
#  'North_Augusta_High_School': 2,
#  'Welkin_Mill,_Lower_Bredbury': 2,
#  'Goldcrest_High_International_School': 5,
#  'The_Cisco_Kid_(1994_film)': 10,
#  'Saboot_(TV_series)': 3,
#  'Bill_Allington': 2,
#  'Riptide_Journal_(book_series)': 7,
#  "Henderson's_Boys:_The_Escape": 3,
#  'Michelangelo_Baracchi_Bonvicini': 6,
#  'Palmer_Mills,_Stockport': 2,
#  'Tony_Michaelides': 3,
#  'Rostik': 2,
#  'KCa_channel': 2,
#  'Henry_K._Landis': 7,
#  'Watrous_Formation': 3,
#  'Ondřej_Čelůstka': 2,
#  'Drifts': 5,
#  'Doris_Miles_Disney': 7,
#  'Émile_Moselly': 4,
#  'Cepola_pauciradiata': 3,
#  'Parienia': 2,
#  'Jasen_walker': 9,
#  'Gatchaman_video_games': 4,
#  'Germany_national_long_track_team': 2,
#  'Far_Arnside': 2,
#  'Union_Nationale_Lycéenne': 4,
#  'Jarapa': 6,
#  'René_Bejarano': 29,
#  'David_Baynton-Power': 37,
#  'Léon_Frapié': 7,
#  'KSLM-LD': 5,
#  'Michael_Odibe': 3,
#  "2009–10_Pacific-10_Conference_women's_basketball_season": 12,
#  'Southwaite': 4,
#  'PT_Bivott': 5,
#  'Prizefight_(CNET_Podcast)': 2,
#  'Michelle_Crawford': 4,
#  'Richard_Onslow,_3rd_Baron_Onslow': 4,
#  'Tricolour_Color': 4,
#  'Afriyie_Acquah': 3,
#  'Workerbee_records': 6,
#  'List_of_marine_fishes_of_the_suborder_Percoidei_of_South_Africa': 8,
#  'Padua,_Ohio': 2,
#  'NAC_Fanzine_De_Rat': 5,
#  'British_Jumping_Derby': 14,
#  'Field_Music_(Measure)': 2,
#  'Lincoln_Court_Shopping_Center': 2,
#  'Beta_Evers': 3,
#  'Difference_between_two_cubes': 2,
#  'Tour_Mélusine': 4,
#  'Gustavo_de_Greiff': 3,
#  'Safari_3000': 12,
#  'X_Games_Snocross': 2,
#  'List_of_Utah_State_University_presidents': 3,
#  'Anglo-Germanophile': 3,
#  'Oatlands_College': 2,
#  'Željko_Stinčić': 3,
#  'Administrative_evil': 4,
#  'Les_Brotteaux': 4,
#  'Síl_Conairi': 14,
#  'First_Presbyterian_Church_(Aurora,_Indiana)': 3,
#  '2008_Acura_Classic': 3,
#  'Hayo_Vierck': 11,
#  'Bob_Gunter': 5,
#  '2009_San_Diego_Open': 2,
#  'Ergün_Berisha': 3,
#  'John_the_Scythian': 6,
#  'Zang_Jialang': 10,
#  'Texas_Comicon': 5,
#  'Iggle_piggle': 3,
#  'Blackberry_Farm': 3,
#  'Nini_Haslund_Gleditsch': 3,
#  'Derailed': 8,
#  'Yonatan_Razel': 5,
#  'First_Aid_Kit_(band)': 9,
#  'Albion_Wharf': 2,
#  "Great_Britain_men's_national_floorball_team": 2,
#  "St._Anthony's_Catholic_Church_(Padua,_Ohio)": 9,
#  'Harbour_Mille_incident': 5,
#  'It_is_what_it_is': 2,
#  'Auditions_(1978_film)': 8,
#  'Jean_Carrière': 9,
#  'SynType_CMS': 3,
#  'Nahanni_Formation': 3,
#  'Enfield_No._2_Mk_I': 3,
#  'Li_Hongchen': 9,
#  'West_Central_High_School': 6,
#  'Johnby': 3,
#  'Raymond_B._Manning': 3,
#  'Nora_Eccles_Harrison_Museum_of_Art': 4,
#  'Today,_Tomorrow,_and_Forever_(box_set)': 2,
#  'Deniz_Özlem': 19,
#  'Vijayanta_ARV': 3,
#  'Max_Hicks': 2,
#  'Lee_mckay': 10,
#  'Princess_Guda_of_Waldeck_and_Pyrmont': 5,
#  'Movable_Cellular_Automata': 4,
#  'Peter_Grubb_(zoologist)': 53,
#  'List_of_Greek_Protected_Designations_of_Origin_cheeses': 11,
#  'Charlbury_Museum': 4,
#  'Phoenician_Ship_Expedition': 3,
#  "St._John's_Evangelical_Lutheran_German_Church_and_Cemetery": 7,
#  'Peter_Grubb': 9,
#  'Gravity_(Pixie_Lott_song)': 10,
#  'Wolverhampton_Wanderers_F.C._season_1959–60': 37,
#  '2,3,5,7-Tetrahydroxy-1,4-naphthalenedione': 6,
#  'Shawn_Luckey': 3,
#  'Minos_Kyriakou': 82,
#  'Copper_Ibuprofenate': 17,
#  '2nd_Regiment_Tennessee_Volunteer_Cavalry': 4,
#  'Mr._Basketball_of_Arkansas': 18,
#  'PLAYER': 6,
#  'Cross_fox_(animal)': 3,
#  'Farewell_Rock': 6,
#  'Utah_Water_Research_Laboratory': 4,
#  'Abdominal_musculature_absent_microphthalmia_joint_laxity': 2,
#  'Waterside_Mill,_Ashton-under-Lyne': 2,
#  'Patrick_Grainville': 3,
#  'International_Intellectual_Property_Institute': 2,
#  'Pierre_Billotte': 7,
#  'Id_Obelus': 5,
#  'Arkwright_Mill,_Rochdale': 2,
#  'All_Saints_Episcopal_School_of_Lubbock': 6,
#  'BOSH_(band)': 2,
#  'Nicki_Richards': 11,
#  'Hubert_Webb_(cricketer)': 2,
#  'Eder_Holguin': 4,
#  'Samuel_Sharpe_(scholar)': 7,
#  'Wolverhampton_Wanderers_F.C._season_1958–59': 30,
#  'Tajerouine': 2,
#  '2,3,5,6,8-Pentahydroxy-1,4-naphthalenedione': 11,
#  'Formosa_surname': 4,
#  'Sakiet_Sidi_Youssef': 2,
#  'Menzel_Salem': 2,
#  'El_Ksour': 2,
#  'Jérissa': 2,
#  'Otto_Hörsing': 7,
#  'Dahmani': 2,
#  'International_Tennis_Open': 2,
#  'Once_(Diana_Vickers_Song)': 7,
#  'ROWVA_High_School': 3,
#  'Souk_Lahad': 3,
#  'El_Golâa': 2,
#  'Didier_Decoin': 3,
#  'Vladimir_Čonč': 2,
#  'Knut_Urban': 5,
#  'Longlevens_junior_school': 2,
#  'Foussana': 2,
#  'Fériana': 2,
#  'Tennessee_State_Route_368': 6,
#  'Papurius': 2,
#  'Sbikha': 2,
#  'Nasrallah,_Tunisia': 2,
#  'Anti-convulsive': 2,
#  'Hajeb_El_Ayoun': 2,
#  'Haffouz': 2,
#  'Lady_Godiva_in_popular_culture': 6,
#  'Oueslatia': 2,
#  'Reserva_nacional_piñeiro_humboldt': 2,
#  'Bou_Hajla': 2,
#  'Fernana': 3,
#  'Saifee_villa': 12,
#  'Rostov_District': 2,
#  'Ramakrishna_Mission_Sri_Koneswara_Hindu_College': 5,
#  'Wolverhampton_Wanderers_F.C._season_1957–58': 19,
#  'Buckingham_potential': 8,
#  'Bou_Salem': 2,
#  'Frédérick_Tristan': 2,
#  'Diyarbakir_Prison': 4,
#  'Lynx_Formation': 3,
#  'Spring_Fever_(manga)': 12,
#  '1961_Rebel_300': 8,
#  'Sadie_West': 2,
#  'Gunnar_Haarstad': 4,
#  'Love_For_Dessert': 13,
#  'Samuel_H._Davis': 2,
#  'No_Gravity_(Shontelle_album)': 3,
#  'Joel_of_Dotawo': 4,
#  'Memorama_(album)': 5,
#  'N._D._Anandarao_Samuel': 2,
#  'John_W._Bowser': 12,
#  'Copper_aspartate': 4,
#  'Stark_County_High_School': 6,
#  'Sylvia_of_Hollywood': 24,
#  'New_unreviewed_article/Andrefernandes': 14,
#  'Dalisandus': 5,
#  'Librophile': 20,
#  'Georg_Schomann': 5,
#  'Redeyef': 2,
#  'Guillermo_Padrés_Elías': 3,
#  'Moularès,_Tunisia': 2,
#  'Métlaoui': 2,
#  'Mdhila': 2,
#  'El_Ksar': 2,
#  'Neda_Agha-Soltan_Graduate_Scholarship': 18,
#  'Zarat,_Tunisia': 2,
#  'Tupelo_Chain_Sex': 3,
#  'Métouia': 2,
#  'Ghannouch': 2,
#  'Welfare_Reform_Act_2009': 2,
#  'Tinja': 3,
#  'This_is_a_Blitz': 6,
#  'Sejenane': 2,
#  'Ras_Jebel': 2,
#  'Raf_Raf': 2,
#  'Metline': 2,
#  'Grzegorz_Paweł_z_Brzezin': 6,
#  'Enabling_transformation': 3,
#  'Fredy_Vera': 2,
#  'Palatka_Gypsy_Band': 21,
#  'Global_Health_Delivery_Project': 3,
#  'Russell_Hill_subway_accident': 2,
#  'Mahavigyan': 3,
#  'Josef_Steindl': 18,
#  "2008–09_Minnesota_Golden_Gophers_women's_ice_hockey_team": 4,
#  'MS_Antivirus_(malware)': 252,
#  'Martin_Šonka': 31,
#  'FGI_Research': 17,
#  'Hollins_Ferry_Road_(Baltimore_City)': 2,
#  'Porcupine_Hills_Formation': 2,
#  'Château_de_Clisson': 3,
#  'Sveshtiplaz': 5,
#  'Magnificence_(History_of_ideas)': 8,
#  'Menzel_Abderrahmane': 2,
#  'Warriors_(History_Channel)': 10,
#  'El_Alia': 3,
#  'Fouchana': 2,
#  'Mohamedia': 2,
#  'Mégrine': 2,
#  'Hammam_Chott': 2,
#  'Ezzahra': 2,
#  'El_Mourouj': 2,
#  'Bou_Mhel_el-Bassatine': 2,
#  'MGS_CL-70': 5,
#  'Zahret_Mediou': 2,
#  'Emperor_Shaka_the_Great': 5,
#  'Casa_Dragones': 10,
#  'Téboursouk': 2,
#  'Nefza': 2,
#  'Pierre_Combescot': 4,
#  'MySupermarket_Insights': 6,
#  'Goubellat': 2,
#  'DJ_Quicksilver': 82,
#  'Ornate_skink': 3,
#  'Internal_nares': 2,
#  'C._James_Block': 8,
#  'Spitfire_(disambiguation)': 139,
#  'Mohammad_Gul_(Helmand_Council)': 2,
#  'Slayden,_Mississippi': 7,
#  'The_Shadows_concert_tours': 2,
#  'Semblance': 3,
#  'Şanlıurfa_GAP_Stadium': 8,
#  'Şanlıurfa_Stadium': 3,
#  'Olympic_Stadium_(ŞanlıUrfa)': 2,
#  'Sakav': 2,
#  'Alan_Maycock': 7,
#  'Jayya': 6,
#  'Mikael_Reuterswärd': 2,
#  'Chief_Governing_Officer': 3,
#  'Sharanga': 2,
#  'Fostered': 2,
#  'Axel_C._Heitmann': 5,
#  'Hipnosis_(band)': 4,
#  'Supermarine_Spitfire': 2710,
#  'Leanne_Smith': 2,
#  'The_Dark_Sea:_Land_of_the_Undead': 18,
#  'Oullim_Spirra': 29,
#  'Zhang_Zhifang': 10,
#  'Gurdwara_Pathar_Sahib': 2,
#  'Hillary_Fisher': 3,
#  '2010_GT4_European_Cup_season': 3,
#  'Holiday_pay_act_1938': 2,
#  'Carrier_Mortar_Tracked': 4,
#  'Gurudwara_Barchha_Sahib': 2,
#  'Alessandro_Elia': 4,
#  'Lars_heikensten': 2,
#  'Cigar_ash': 3,
#  'Hormone_imbalance': 2,
#  'Pietro_Floridia': 2,
#  'Pammenopsis': 2,
#  'Rollergames_(arcade_game)': 2,
#  'Talib_(disambiguation)': 5,
#  'Kveda_Sakara': 8,
#  'Windy_505': 3,
#  'Second_Chance_Kids': 2,
#  'Baba_nand_singh': 2,
#  'Zerkalʹnaya_sturya': 8,
#  '1952–53_FDGB-Pokal': 8,
#  'THIRUPAMPURAM': 17,
#  'Get_Out_of_Our_House': 2,
#  'Alastair_Macdonald': 9,
#  'Château_de_Pornic': 2,
#  'Jimmy_Cochran': 2,
#  'NCB_Reconnaissance_Vehicle': 2,
#  '2006_Gulf_Club_Champions_Cup': 3,
#  'Jan_Jakob_Maria_de_Groot': 5,
#  'David_Michôd': 5,
#  '1985_Diethylene_Glycol_Wine_Scandal': 27,
#  'Goldeneye_Hotel_and_Resort': 3,
#  'Leon_Gellert': 2,
#  'NBC_Reconnaissance_Vehicle_(Drdo)': 2,
#  'Bremner': 5,
#  'James_Roy_Andersen': 3,
#  'NBC_Reconnaissance_Vehicle': 6,
#  'Zvi_Shiloah': 2,
#  'Edwin_Eziyodawe': 2,
#  'Scrawly': 2,
#  'Tubal_occlusion': 2,
#  'History_of_the_Bronx': 6,
#  'Robert_W._Madden': 2,
#  'Sister_Antonia_Brenner': 2,
#  'Riva_Philip': 2,
#  'Rotna': 4,
#  'Mother_Antonia_Brenner': 2,
#  'Proton-Electrotex,JSC': 4,
#  'Antonia_Brenner': 2,
#  'Alhassane_Dosso': 3,
#  'Sam_Nippress': 7,
#  'Mighty_blade_rpg': 2,
#  'Troublesome_Night_8': 3,
#  'İstanbul_Büyükşehir_Belediyesi_S.K.': 7,
#  'İstanbul_Büyükşehir_Belediyesi': 2,
#  'İstanbul_Büyükşehir_Belediyespor': 2,
#  "One_More_Night_(Luv'_Album)": 4,
#  'Kukuraja': 38,
#  'Armoured_Amphibious_Dozer': 2,
#  'Mail_Express_Trains_Of_India': 2,
#  'Sergio_Reyna': 3,
#  'U.S._2003_State_of_the_Union_address': 2,
#  '2011_United_States_federal_budget': 7,
#  'William_Crowther_(New_Zealand)': 3,
#  'Caixin_Media': 5,
#  'List_of_the_Famous_People_from_Pathanamthitta_District': 8,
#  'Chippenham_and_Calne_Line': 2,
#  'IAFIE': 4,
#  'Philadelphia_Athletics_(1890–1891)_all-time_roster': 7,
#  'Wikka_(album)': 2,
#  'William_Joseph_Napier': 3,
#  'Apache_Mobile_Filter': 8,
#  'EmTRAiN': 5,
#  'Indian_Association_for_Islamic_Economics': 21,
#  'Collingwood_Primary_School': 3,
#  'Suseni_tribe': 2,
#  'Isidor_Clinton_Rubin': 17,
#  'Black_FireLand': 2,
#  'Network_as_a_service': 2,
#  'Cowboys_and_Outlaws': 2,
#  'Chandi_Devi_Temple,_Haridwar': 19,
#  'Muay_Thai_in_popular_culture': 8,
#  'The_Apple_Byte': 6,
#  'Maya_Devi_Temple,_Haridwar': 11,
#  'Logan_the_huge': 3,
#  'Rugby_League_Conference_North_West_Premier': 27,
#  'Andrey,_Metropolitan_of_New_York': 30,
#  'In_The_Mirror': 5,
#  'Ngotwane_Dam': 2,
#  'Mansa_Devi_Temple,_Haridwar': 12,
#  'Wolf-Dietrich_Huy': 3,
#  'A_Wicked_Ghost_III:_The_Possession': 2,
#  'United_Nations_Security_Council_Resolution_522': 2,
#  'Range_3_Coast_Land_District': 3,
#  'Joseph_Witheford': 3,
#  'Bangladesh_engineering': 3,
#  'Quentin_Jardine': 7,
#  'Shadow_hearts_sanatorium': 5,
#  'Brian_Tong': 8,
#  'Nor_Cal_Red_Hawks': 3,
#  'Mohale_Dam': 5,
#  'Ellichpur_district': 2,
#  'Hugo_Filipe_Da_Costa_Vieira': 3,
#  'Assi_Koivisto': 3,
#  'The_Driscoll_Brothers': 2,
#  "Young_Scientists'_Association_of_Kyiv_National_University": 4,
#  'Anitra_Ahtola': 2,
#  'Larri_Passos': 2,
#  'Horsehead_Water_Ski_Club': 16,
#  'RTV_Studio_B': 12,
#  'Rufigallol': 2,
#  'School_of_Senior_Civil_Service': 4,
#  'Ashley_Jackson_(historian)': 2,
#  'Cormar_carpets': 2,
#  'Beloribitsa': 2,
#  'Price_Chopper_/_Price_Mart': 2,
#  'JRA_Award': 4,
#  'Jari_Komulainen': 5,
#  'Felix_McGuire': 4,
#  'Kabul_Health_Sciences_Institute': 16,
#  'Palmiet_River': 2,
#  'The_Ukrainian_Register_Cossacks': 17,
#  'Minerul_Cavnic': 4,
#  'Alsace-Moselle': 2,
#  'Rottnan': 6,
#  'Danzig_Wharf,_Rotherhithe': 12,
#  'Tolu-e-Islam_(magazine)': 17,
#  'Albion_Wharf,_Rotherhithe': 6,
#  'M.G.Srinivas': 3,
#  'Matthew_Kirkbride': 3,
#  'Members_of_the_New_South_Wales_Legislative_Assembly,_1920–1922': 4,
#  'Pumpy_Tudors': 5,
#  'List_of_Judas_Priest_awards_and_nominations': 7,
#  'R._Stevenson_(rugby_player)': 2,
#  'Robert_Morrow_Houston': 3,
#  'Specializations_in_mba': 2,
#  'International_Cloud_Experiment': 7,
#  'Bangladesh_Youth_Leadership_Center': 6,
#  'VivaCité': 3,
#  'List_of_Joint_Committees_(UK_Local_Government)': 7,
#  'C.G._Timms': 2,
#  'Ashley_Jackson': 2,
#  'Michael_Legat': 3,
#  'R.C._Stevenson': 2,
#  'Krohn_Air': 2,
#  'Heinrich_IV,_Prince_Reuss_of_Köstritz': 11,
#  'Jamesway_hut': 3,
#  'Behind_the_Holy_Edges:_Walter_and_Connies_Story': 19,
#  'List_of_preserved_historic_blast_furnaces': 12,
#  'Carl_Adolf_Feilberg': 60,
#  'Collège_du_Saint-Esprit': 3,
#  'Jamrud_band': 3,
#  'Collège_du_Saint-Esprit,_Quatre_Bornes': 3,
#  'Acrofrontofacionasal_dysostosis': 7,
#  '2010_Thai_Division_2_League_Bangkok_&_field_Region': 3,
#  'Bolte_Ministry': 10,
#  'Gilbert_Carson_(New_Zealand)': 3,
#  'List_of_Metrolink_stations': 3,
#  'Geoffrey_Chew_(musicologist)': 4,
#  'Kaboora_Institute_of_Higher_Education': 8,
#  'Costa_Deliziosa': 13,
#  'List_of_Dr_Dre_awards_and_nominations': 5,
#  'Mors_lilla_olle': 3,
#  'Galaxie_Amneville': 8,
#  'Belgrade_Prophetologion': 4,
#  '12th_Pioneers_(The_Kelat-i-Ghilzie_Regiment)': 2,
#  'Midwest_Veterans_Writers_Workshop': 3,
#  'Tarun_Rathi': 9,
#  'Max_Markson': 8,
#  'Avraham_Yosef_Shapira': 2,
#  'Archibald_Willis': 3,
#  'OJSC_Polymetal': 3,
#  'Pulp_(Filipino_music_magazine)': 3,
#  'City_University_of_New_York_School_of_Law': 113,
#  'Members_of_the_Victorian_Legislative_Assembly,_1955–1958': 2,
#  'Illarikam': 31,
#  'Keyla_Ohs': 3,
#  'Some_Great_Reward_Tour': 7,
#  'MZ_twin': 2,
#  'Pass_by_value': 2,
#  'Ciliary_injection': 2,
#  'Ciliary_hyperemia': 2,
#  'East_Hills_Hostel': 7,
#  'Vietnam_Colony': 2,
#  'Concentric_groove': 2,
#  'Farrah_damji': 2,
#  'Emilio_Greco': 2,
#  '54th_Missile_Division': 2,
#  'Colorz_of_Rage': 8,
#  'Steven_T._Wax': 14,
#  'Descendants_of_James_VI_of_Scotland': 3,
#  'Sembanarkoil': 12,
#  'Studio_total': 6,
#  'Courts_Boards': 4,
#  'Descendants_of_Prince_Ludwig_von_Anhalt-Zerbst': 4,
#  'List_of_Famous_Arabic_People': 3,
#  'Le_Militant': 5,
#  'James_C._Johnson': 8,
#  'Ben_Grosse': 6,
#  "2010_Dubai_Tennis_Championships_–_Men's_Singles": 3,
#  'Francesco_Somaini': 18,
#  '2010_Dubai_Tennis_Championships': 4,
#  'Yamatoot': 4,
#  'Isabel_Rey': 15,
#  'Ysgol_Gyfun_Bro_Morgannwg': 4,
#  'Nannastacus': 2,
#  'St._John_of_Rila_Church,_Targovishte': 27,
#  'Prozeda': 8,
#  'Ann_Farholt': 6,
#  'Betsy_Rue': 8,
#  'List_of_wars_involving_Israel': 2,
#  'Command_Loss_Timer_Reset': 7,
#  'List_of_CJK_Unified_Ideographs,_Extension_A_(3400-4DBF)': 23,
#  'Yoolinkpro': 10,
#  'Scpc_/_dvb': 2,
#  'Italian_Senate_election_in_Lombardy,_2006': 8,
#  'Esther_Bigeou': 3,
#  'Jason_Farradane': 7,
#  'Santeri_Nuorteva': 7,
#  'Veronika_Vítková': 3,
#  'Ham_Wall': 2,
#  'Edward_Gordon': 4,
#  'Troublesome_Night_7': 3,
#  'Opération_Séisme_Haiti_2010': 12,
#  'Sleep_box': 5,
#  'Joan_Vaux,_Lady_Guildford': 40,
#  'M.S_Tripunithura': 2,
#  'List_of_Delta_Chi_brothers': 2,
#  'Radisson_Blu_Iveria_Hotel,_Tbilisi': 5,
#  'Sembanarkoil_(State_Assembly_Constituency)': 12,
#  'Castalin': 5,
#  'List_of_Alpha_Chi_Sigma_chapters': 2,
#  'Pedro_Venâncio': 4,
#  'Erik_Brandt': 7,
#  'Megan_McJames': 2,
#  'Kokoro_no_Uta': 2,
#  'White_clipper': 3,
#  'Huntroyde_Hall': 14,
#  'TY_KU': 6,
#  'Eat_That_Frog': 3,
#  'Salon_du_Chocolat': 2,
#  'Hailey_Duke': 3,
#  'Midreshet_Aviv': 4,
#  'Neo-Tiwanakan_architecture': 16,
#  'HP_Slate': 7,
#  'List_of_songs_by_Nick_Jonas_and_the_Administration': 34,
#  'Asymptotic_theory_(statistics)': 6,
#  'Shirra_Kenworthy': 2,
#  'Tawhaki_Vallis': 5,
#  'Kristiyan_Koev': 5,
#  'Troublesome_Night_6': 4,
#  'County_Route_E1_(California)': 2,
#  'Bower,_South_Australia': 5,
#  'John_Allen_(miner)': 5,
#  'Francis_Wilson_(lichenologist)': 2,
#  'Pakistan_tehreek_insaf': 2,
#  'Max_Koch': 2,
#  'MobileReflex(Mobile_Framework)': 2,
#  'Raleigh_Black': 2,
#  'Joji_ilagan_bian': 3,
#  'Littérature:_New_Series': 2,
#  'PalaisQuartier': 2,
#  'Colegio_de_Ingenieros_y_Agrimensores_de_Puerto_Rico': 3,
#  'Microcosm:_E._coli_and_the_New_Science_of_Life': 2,
#  'John_Richardson_(convict)': 2,
#  '197856_Tafelmusik': 26,
#  'Tora-san_to_the_Rescue': 2,
#  '24th_Midsouth_Emmy_Awards': 2,
#  'Home_Fire': 6,
#  '33rd_Guards_Missile_Army': 2,
#  'Sam_Trimble_(designer)': 8,
#  'Union_Territory_(India)': 131,
#  'Bitter_Virgin': 2,
#  'Bryheem_Hancock': 2,
#  'Mar_Babai_I': 4,
#  'The_Hand_of_Glory': 4,
#  'Min-Sheng_General_Hospital': 13,
#  'Frank_Lethbridge': 3,
#  "Tora-san's_Easy_Advice": 2,
#  'Job_Vile': 2,
#  'Peter_Symes': 4,
#  'Parlé_magazine': 3,
#  'Charles_Hayward_Izard': 4,
#  'Hotel_ulaanbaatar': 5,
#  'Search_and_Destroy_(play)': 2,
#  'Black_Belt_(Film)': 2,
#  'José_Luiz_de_Oliveira': 3,
#  'Ulaanbaatar_Hotel': 6,
#  'Osvaldo_Velloso_de_Barros': 3,
#  'Teóphilo_Bettencourt_Pereira': 3,
#  'Moacyr_Siqueira_de_Queiroz': 3,
#  'Policarpo_Ribeiro_de_Oliveira': 3,
#  'Manoel_de_Aguiar_Fagundes': 3,
#  'Mar_Aba': 2,
#  'Clergy_housing_allowance': 2,
#  'List_of_mayors_of_Madison,_Wisconsin': 5,
#  'Joel_de_Oliveira_Monteiro': 3,
#  'Luiz_Gervazoni': 3,
#  "List_of_characters_of_Dante's_Inferno": 14,
#  "Tora-san's_Matchmaker": 3,
#  'Hermógenes_Fonseca': 3,
#  'Agostinho_Fortes_Filho': 3,
#  'Alfredo_Almeida_Rego': 3,
#  "Characters_of_Dante's_Inferno": 2,
#  'Humberto_de_Araújo_Benevenuto': 3,
#  ...}

# %%
#plot distribution of edit amts
edit_vals = list(edit_num.values())
edit_vals_hist = sns.distplot(edit_vals, bins = 1)
edit_vals_hist
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
num_edits_mean = statistics.mean(edit_vals)
num_edits_mean
# Out:
# 47.33549788536329

# %%
def get_top_10(wiki_dict):
    wiki_dict2 = sorted(wiki_dict.items(), key = lambda x: x[1], reverse = True)
    df = pd.DataFrame(wiki_dict2[:11])
    df.rename(columns={0: "Article", 1: "Edit Count"}, inplace = True)
    return df
def get_bottom_10(wiki_dict):
    wiki_dict2 = sorted(wiki_dict.items(), key = lambda x: x[1])
    df = pd.DataFrame(wiki_dict2[:11])
    df.rename(columns={0: "Article", 1: "Edit Count"}, inplace = True)
    return df

# %%
get_bottom_10(edit_num)
# Out:
#                                  Article  Edit Count
# 0               Welling_(disambiguation)           0
# 1              [[it:Depressione (maZ 0 8           0
# 2                         [[id:Depresi]]           0
# 3              [[hr:Klinička depresija]]           0
# 4                             [[ko:우울증]]           0
# 5           [[fr:Dépression (médecine)]]           0
# 6                         [[eo:Deprimo]]           0
# 7                       [[es:Depresión]]           0
# 8   [[el:Μείζων καταθλιπτική διαταραχή]]           0
# 9                     [[et:Depressioon]]           0
# 10                     [[de:Depression]]           0

# %%
#get_top_10(edit_num)
# Out:
#                                             Article  Edit Count
# 0                                    George_W._Bush       43650
# 1   List_of_World_Wrestling_Entertainment_employees       30572
# 2                                         Wikipedia       29726
# 3                                     United_States       27433
# 4                                   Michael_Jackson       23243
# 5                                             Jesus       21768
# 6                                    Deaths_in_2009       20814
# 7                                               Wii       20225
# 8                                      Adolf_Hitler       20093
# 9                                    Britney_Spears       19833
# 10                                     World_War_II       19576

# %%
top10least = pd.DataFrame(j[:11])
top10least.rename(columns={0: "Article", 1: "Edit Count"},
                     inplace=True)
top10least
# Out:
#                                  article  Edit Count
# 0               Welling_(disambiguation)           0
# 1              [[it:Depressione (maZ 0 8           0
# 2                         [[id:Depresi]]           0
# 3              [[hr:Klinička depresija]]           0
# 4                             [[ko:우울증]]           0
# 5           [[fr:Dépression (médecine)]]           0
# 6                         [[eo:Deprimo]]           0
# 7                       [[es:Depresión]]           0
# 8   [[el:Μείζων καταθλιπτική διαταραχή]]           0
# 9                     [[et:Depressioon]]           0
# 10                     [[de:Depression]]           0

# %%
k = get_top_10(edit_num)
top10most = pd.DataFrame(k[:11])
top10most.rename(columns={0: "Article", 1: "Edit Count"},
                     inplace=True)
top10most
# Out:
#                                             Article  Edit Count
# 0                                    George_W._Bush       43650
# 1   List_of_World_Wrestling_Entertainment_employees       30572
# 2                                         Wikipedia       29726
# 3                                     United_States       27433
# 4                                   Michael_Jackson       23243
# 5                                             Jesus       21768
# 6                                    Deaths_in_2009       20814
# 7                                               Wii       20225
# 8                                      Adolf_Hitler       20093
# 9                                    Britney_Spears       19833
# 10                                     World_War_II       19576

# %% [markdown]
# ## Get M stat

# %%
def get_pairs(tup_pairs):
    if len(tup_pairs) == 0:
        return {}
    
    mut_revs = {}
    checked = []
    
    for i in tup_pairs:
        if i in checked:
            continue
        if (i[1], i[0]) in checked:
            continue
        checked.append(i)
        
        for mut_revs in tup_pairs:
            if tup_pairs == (i[1], i[0]):
                if i in mut_revs:
                    mut_revs[i] = mut_revs[i] + 1
                else:
                    mut_revs[i] = 1
                    
    return mut_revs

def get_M_perArt(revs, mut_amt, edit_num):
    if len(revs) == 0:
        return 0
    
    total = 0
    for i in revs:
        total = total+min(edit_num[i[0]], edit_num[i[1]])
    
    final = (len(mut_amt) * total)
    
    return final

def dicts_of_genInfo(e):
    edit_num = {}
    editor_name = {}
    
    for i in sorted(e.keys(), reverse = True):
        time = e[i][0]
        if e[i][2] != "":
            revert = int(e[i][1])
        else:
            continue
        if e[i][2] != "":
            version = int(e[i][2])
        else:
            continue
        #revert = int(e[i][1])
        #version = int(e[i][2])
        editor = e[i][3]
        
        if editor in edit_num:
            edit_num[editor] = edit_num[editor] +1
        else:
            edit_num[editor] = 1

        if revert == 0:
            editor_name[version] = editor
    return edit_num, editor_name

# %%
def get_m_stat(e, m_val): 
    topic = e["title"]
    del e["title"]
    edit_num, editor = dicts_of_genInfo(e)
    
    t = []
    
    for i in sorted(e.keys(), reverse = True):
        time = e[i][0]
        if e[i][2] != "":
            revert = int(e[i][1])
        else:
            continue
        if e[i][2] != "":
            version = int(e[i][2])
        else:
            continue
        #revert = int(e[i][1])
        #version = int(e[i][2])
        editor_name = e[i][3]
        
        if revert == 1:
            try:
                rival = editor[version+1]
                t.append((editor_name, rival))
            except:
                continue

    mut_pairs_amt = get_pairs(t)
    m_val = get_M_perArt(t, mut_pairs_amt, edit_num)
    
    return m_val 


def final_M_stat():
    file = open("en_light_dump.txt/en_wiki.txt", "r")
    #file = open(r"en_light_dump.txt/en_wiki.txt", "r")
    get_each_(file)
    
def get_each_M(file):
    m_holder = {}
    
    title_dict = {}
    title_dict["title"] = file.readline()
    
    num_edit = 0
    for i in file:
        if i[0] != "^":
            new_title = title_dict.copy()
            m_val = get_m_stat(new_title, m_holder)
            m_holder[title_dict["title"]] = m_val
            
            #print(new_topic)
            #print("~~~")
            
            title_dict = {}
            title_dict["title"] = i
            edit_num = 0
        else: 
            title_dict[num_edit] = i.split(" ")
        
        num_edit = num_edit +1 
        
    new_title = title_dict.copy()
    m_val = get_m_stat(new_title, m_holder)
    m_holder[title_dict["title"]] = m_val
    
#     print("Top 10:")
#     print(get_top_10(m_holder))
    
#     print("Bottom 10:")
#     print(get_bottom_10(m_holder))
    
    #print("Top Ten:")
    #[print("topic: ",k, " m statistic: ", v) for k, v in sorted(m_holder.items(), key=lambda x: x[1], reverse=True)[:11]]
    print("\nBottom Ten:")
    [print("topic: ",k, " m value: ", v) for k, v in sorted(m_holder.items(), key=lambda x: x[1], reverse = True)[-10:]]
    
    file.close()

# %%
final_M_stat()
# Out:
# Top Ten:
# topic:  Chevrolet_Vega
#   m statistic:  2650352
# topic:  Goan_Catholics
#   m statistic:  1503698
# topic:  Neurofunk
#   m statistic:  733164
# topic:  FC_Singen_04
#   m statistic:  676478
# topic:  Michael_Jackson
#   m statistic:  533290
# topic:  List_of_World_Wrestling_Entertainment_employees
#   m statistic:  515480
# topic:  Voodoo_(D'Angelo_album)
#   m statistic:  441798
# topic:  Anarchism
#   m statistic:  432828
# topic:  Ozark_Jubilee
#   m statistic:  430898
# topic:  Catholic_Church
#   m statistic:  342206
# topic:  List_of_Barney_&_Friends_episodes_and_videos
#   m statistic:  324980

# %%
final_M_stat()
# Out:
# Bottom Ten:
# topic:  AlbaniaPeople
#   m value:  0
# topic:  AlbaniaHistory
#   m value:  0
# topic:  AmoeboidTaxa
#   m value:  0
# topic:  AssistiveTechnology
#   m value:  0
# topic:  AfghanistanTransnationalIssues
#   m value:  0
# topic:  AfghanistanMilitary
#   m value:  0
# topic:  AfghanistanCommunications
#   m value:  0
# topic:  AfghanistanPeople
#   m value:  0
# topic:  AfghanistanGeography
#   m value:  0
# topic:  AfghanistanHistory
#   m value:  0

# %%
final_M_stat()
# Out:
# Top Ten:
# topic:  List_of_World_Wrestling_Entertainment_employees
#   m statistic:  87373860
# topic:  Michael_Jackson
#   m statistic:  49862615
# topic:  Anarchism
#   m statistic:  33760584
# topic:  George_W._Bush
#   m statistic:  32263428
# topic:  Neurofunk
#   m statistic:  22728084
# topic:  Muhammad
#   m statistic:  18140598
# topic:  Catholic_Church
#   m statistic:  17794712
# topic:  Global_warming
#   m statistic:  16442440
# topic:  Real_Madrid_C.F.
#   m statistic:  15733025
# topic:  Barack_Obama
#   m statistic:  14544492
# topic:  United_States
#   m statistic:  13853504

# %%
final_M_stat()
# Out:
# Bottom Ten:
# topic:  AlbaniaHistory
#   m value:  0
# topic:  AmoeboidTaxa
#   m value:  0
# topic:  AssistiveTechnology
#   m value:  0
# topic:  AfghanistanTransnationalIssues
#   m value:  0
# topic:  AfghanistanMilitary
#   m value:  0
# topic:  AfghanistanTransportations
#   m value:  0
# topic:  AfghanistanCommunications
#   m value:  0
# topic:  AfghanistanPeople
#   m value:  0
# topic:  AfghanistanGeography
#   m value:  0
# topic:  AfghanistanHistory
#   m value:  0

# %%
#for top 10
final_M_stat()
# Out:
# Top Ten:
# topic:  List_of_World_Wrestling_Entertainment_employees
#   m statistic:  87373860
# topic:  Michael_Jackson
#   m statistic:  49862615
# topic:  Anarchism
#   m statistic:  33760584
# topic:  George_W._Bush
#   m statistic:  32263428
# topic:  Neurofunk
#   m statistic:  22728084
# topic:  Muhammad
#   m statistic:  18140598
# topic:  Catholic_Church
#   m statistic:  17794712
# topic:  Global_warming
#   m statistic:  16442440
# topic:  Real_Madrid_C.F.
#   m statistic:  15733025
# topic:  Barack_Obama
#   m statistic:  14544492
